# %%
from pathlib import Path
from datetime import datetime
import re
import pandas as pd
import os

DATA_DIR = Path("/Users/kmaxx/Desktop/IDX-da/idx_final_data")

sold_df = pd.read_csv(DATA_DIR / "sold_final_outliers_removed.csv", low_memory= False)

# %%
"ListAgentFullName" in sold_df.columns
# Out:
# True
