# %% [markdown]
# # **WEEK 1 - Monthly Datasets Aggregation**

# %% [markdown]
# Goal :
# - Combined sold transactions dataset
# - Combined listing data dataset

# %% [markdown]
# ### Set Up

# %%
from pathlib import Path
from datetime import datetime
import re
import pandas as pd
import os

DATA_DIR = Path("/Users/kmaxx/Desktop/IDX-da/idx_data")

SOLD_PREFIX = "CRMLSSold"
LISTING_PREFIX = "CRMLSListing"

# %% [markdown]
# ### Combine Sold Datasets

# %%
combined_sold = pd.DataFrame()
total_before_concat = 0

files = []

for file in Path(DATA_DIR).iterdir():
    if "filled" not in file.name and SOLD_PREFIX in file.name:
        df = pd.read_csv(file, low_memory=False)
        total_before_concat += len(df)
        files.append(df)

combined_sold = pd.concat(files, ignore_index=True)

print(f"Total rows before concatenation: {total_before_concat:,}")
print(f"Total rows after concatenation:  {len(combined_sold):,}")
# Out:
# Total rows before concatenation: 569,886
# Total rows after concatenation:  569,886

# %%
sold_residential_filter = combined_sold[combined_sold["PropertyType"] == "Residential"]
print(f"Total rows after Residential filter: {len(sold_residential_filter):,}")
# Out:
# Total rows after Residential filter: 384,216

# %% [markdown]
# ### Combine Listing Datasets

# %%
combined_listing = pd.DataFrame()
total_before_concat = 0

files = []

for file in Path(DATA_DIR).iterdir():
    if "filled" not in file.name and LISTING_PREFIX in file.name:
        df = pd.read_csv(file, low_memory=False)
        total_before_concat += len(df)
        files.append(df)

combined_listing = pd.concat(files, ignore_index=True)

print(f"Total rows before concatenation: {total_before_concat:,}")
print(f"Total rows after concatenation:  {len(combined_listing):,}")
# Out:
# Total rows before concatenation: 966,475
# Total rows after concatenation:  966,475

# %%
listing_residential_filter = combined_listing[combined_listing["PropertyType"] == "Residential"]
print(f"Total rows after Residential filter: {len(listing_residential_filter):,}")
# Out:
# Total rows after Residential filter: 567,549

# %% [markdown]
# ### Export

# %%
combined_sold.to_csv(DATA_DIR/ "combined_sold.csv", index = False)
combined_listing.to_csv(DATA_DIR / "combined_listing.csv", index = False)

# %%
sold_residential_filter.to_csv(DATA_DIR / "sold_residential_filter.csv", index=False)
listing_residential_filter.to_csv(DATA_DIR / "listing_residential_filter.csv", index=False)
